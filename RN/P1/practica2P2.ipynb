# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

celsius=np.array([-40,-10,0,8,15,22,38,42,30],dtype=float)
farenheit=np.array([-40,14,32,46,59,72,100,107.6,86])

# %% [markdown]
# Capas y modelo

# %%
oculta1=tf.keras.layers.Dense(units=3,input_shape=[1])
oculta2=tf.keras.layers.Dense(units=3)
salida=tf.keras.layers.Dense(units=1)
modelo=tf.keras.Sequential([oculta1,oculta2,salida])

modelo.compile(
    optimizer=tf.keras.optimizers.Adam(.1),
    loss="mean_squared_error"
)

# %% [markdown]
# Entrenamiento

# %%
historial=modelo.fit(celsius,farenheit,epochs=1000,verbose=False)
plt.xlabel("# epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])
plt.show()
# Out:
# WARNING:tensorflow:From d:\anaconda3\envs\tensorflow-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
result=modelo.predict([100.00])
print("El resultado es "+str(result)+" Farenheit")

print("Variables internas del modelo")
print(oculta1.get_weights())
# Out:
# 1/1 [==============================] - 0s 36ms/step
# El resultado es [[211.8742]] Farenheit
# Variables internas del modelo
# [array([[-0.53257763,  0.17720053, -0.3415137 ]], dtype=float32), array([-3.99622  ,  3.9619951, -3.4926977], dtype=float32)]
